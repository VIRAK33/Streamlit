# %%
import pandas as pd
import numpy as np
import seaborn as sns


df1 = pd.read_csv('moodleitcdata.csv')

# %%
import pandas as pd
md =pd.read_csv('moodleitcdata.csv')
md = md.rename(columns={'userid':'ID', 'username': 'Username', 'firstname':'Student Name', 'phone1':'Sex', 'department':'Department', 'lastname':'Group', 'courseName':'Course Name', 'moduleName':'Module Name', 'completionstate': 'State', 'CompletionDate':'Completion Date'})
 

progress = md[(md['State'] == 1) & (md['Completion Date'] >= str(startDate)) & (md['Completion Date'] <= str(endDate))]
# pg = progress.groupby(['Student Name','Course Name']).count()
# print(pg[['ID']])
arr = []
for i in range(0, len(progress)):
    name = progress.iloc[i][2]
    sex =  progress.iloc[i][3]
    course = progress.iloc[i][6]

    completed = progress[progress['Student Name'] == name].count()


    if [name, sex,course, completed[0]] not in arr:
        arr.insert(i, [name, sex, course, completed[0]])


pro = pd.DataFrame(arr, columns = ['Student Name', 'Sex', 'Course', 'Completed'])
pro.sort_values(by=['Student Name'], inplace=True)


plt.figure(figsize=(10,10), dpi=250)
g2 = sns.countplot(hue= "Sex",y="Course",  data=pro)
plt.yticks(rotation = 45)
for p in g2.patches:
        percentage = '{:.0f}'.format(p.get_width())
        x = p.get_x() + p.get_width() + 0.02
        y = (p.get_y() + p.get_height()/2) + 0.15
        g2.annotate(percentage, (x, y))

# %%
import pandas as pd
md =pd.read_csv('moodleitcdata.csv')
md = md.rename(columns={'userid':'ID', 'username': 'Username', 'firstname':'Student Name', 'phone1':'Sex', 'department':'Department', 'lastname':'Group', 'courseName':'Course Name', 'moduleName':'Module Name', 'completionstate': 'State', 'CompletionDate':'Completion Date'})
 
startDate = '2020-09-12 00:00:00'
endDate = '2020-12-20 00:00:00'

course = 'Climate Change and Adaptation'

progress = md[(md['State'] == 1) & (md['Completion Date'] >= str(startDate)) & (md['Completion Date'] <= str(endDate)) & (md['Course Name'] == course)]
# pg = progress.groupby(['Student Name','Course Name']).count()
# print(pg[['ID']])
arr = []
for i in range(0, len(progress)):
    name = progress.iloc[i][2]
    sex =  progress.iloc[i][3]
    course = progress.iloc[i][6]

    completed = progress[progress['Student Name'] == name].count()


    if [name, sex,course, completed[0]] not in arr:
        arr.insert(i, [name, sex, course, completed[0]])


pro = pd.DataFrame(arr, columns = ['Student Name', 'Sex', 'Course', 'Completed'])
pro.sort_values(by=['Student Name'], inplace=True)
# c1, c2 = st.beta_columns(2)
# with c1:
# #     st.dataframe(data=pro, height=600)
#     pro
# with c2:
totalRecord = pro['Completed'].count()
if totalRecord > 25:
    s = plt.figure(figsize=(10,20))
    g2 = sns.barplot(y=pro['Student Name'], x= pro['Completed'])

    plt.title("Student Learing Progress")
    plt.xlabel('Completed Courses')
    plt.ylabel('Student Name')
#     plt.ylim(0, 50)
    # plt.show()
    plt.savefig('images/Student Learning Proress/'+ str(i) +'.png', bbox_inches='tight')
    s
else:
    s = plt.figure()
    g2 = sns.barplot(y=pro['Student Name'], x= pro['Completed'])

    plt.title("Student Learing Progress")
    plt.xlabel('Completed Courses')
    plt.ylabel('Student Name')
    # plt.ylim(0, 25)
    # plt.show()
    plt.savefig('images/Student Learning Proress/'+ str(i) +'.png', bbox_inches='tight')
    s
# progress
# a = progress["ID"].unique()
print(len(a))
# Out:
# 40
#      ID   Username         Student Name  Sex Department     Group  \
# 0   227  e20160244      Kheav Mony Reth    M        GRU  I5-WRI-A
# 1   263  e20160806  Veth Vathanachannbo    M        GRU  I5-WRI-B
# 2   206  e20160046          Chea Hormey    F        GRU  I5-WRI-A
# 3   261  e20160705          Tai Sovandy    M        GRU  I5-WRI-B
# 4   232  e20160335      Lin Leang Puthy    M        GRU  I5-WRI-A
# 5   264  e20160821          Yao Thapiya    M        GRU  I5-WRI-B
# 6   238  e20181651            Neom Nich    M        GRU  I5-WRI-B
# 7   239  e20160452           Oeng Hokly    M        GRU  I5-WRI-B
# 8   259  e20160680         Srorn Piseth    M        GRU  I5-WRI-B
# 9   251  e20160550     Ros Khematakavid    M        GRU  I5-WRI-B
# 10  230  e20160312            Lay Rithy    M        GRU  I5-WRI-A
# 11  228  e20160248  Kheng Chanchorornay    F        GRU  I5-WRI-A
# 12  250  e20160513          Po Sochetra    M        GRU  I5-WRI-B
# 13  243  e20160475           Pen Piseth    M        GRU  I5-WRI-B
# 14  266  e20160828            Yet Tokyo    M        GRU  I5-WRI-B
# 15  220  e20160196          Hort Bunnet    M        GRU  I5-WRI-A
# 16  222  e20160224      Kea Taing Srorn    M        GRU  I5-WRI-A
# 17  209  e20150152              Dorn Da    M        GRU  I5-WRI-A
# 18  218  e20160170        Heng Sorphorn    F        GRU  I5-WRI-A
# 19  223  e20160229            Ken Sombo    M        GRU  I5-WRI-A
# 20  241  e20160490          Pech Ponleu    M        GRU  I5-WRI-B
# 21  216  e20160158     Hen Chhordaneath    F        GRU  I5-WRI-A
# 22  205  e20150027    Chaing Seyhakmony    M        GRU  I5-WRI-A
# 23  249  e20160494       Phy Sophea Rom    M        GRU  I5-WRI-B
# 24  213  e20160147           Hay Lyhour    M        GRU  I5-WRI-A
# 25  254  e20160598         Seng Ponlork    M        GRU  I5-WRI-B
# 26  238  e20181651            Neom Nich    M        GRU  I5-WRI-B
# 27  266  e20160828            Yet Tokyo    M        GRU  I5-WRI-B
# 28  225  e20160239    KHANNRA Chhaiyuth    M        GRU  I5-WRI-A
# 29  236  e20160386        Men Keo Ratha    M        GRU  I5-WRI-B
# 30   18  hakdaneth                  HAK    F        GRU    Daneth
# 31  205  e20150027    Chaing Seyhakmony    M        GRU  I5-WRI-A
# 32  258  e20160671           Sreang Mom    F        GRU  I5-WRI-B
# 33  266  e20160828            Yet Tokyo    M        GRU  I5-WRI-B
# 34  236  e20160386        Men Keo Ratha    M        GRU  I5-WRI-B
# 35  225  e20160239    KHANNRA Chhaiyuth    M        GRU  I5-WRI-A
# 36  220  e20160196          Hort Bunnet    M        GRU  I5-WRI-A
# 37  218  e20160170        Heng Sorphorn    F        GRU  I5-WRI-A
# 38  267  e20150744            Tho Borin    M        GRU  I5-WRI-B
# 39  247  e20160496    Phoeun So Phanith    M        GRU  I5-WRI-B
# 40  263  e20160806  Veth Vathanachannbo    M        GRU  I5-WRI-B
# 41  230  e20160312            Lay Rithy    M        GRU  I5-WRI-A
# 42  216  e20160158     Hen Chhordaneath    F        GRU  I5-WRI-A
# 43  243  e20160475           Pen Piseth    M        GRU  I5-WRI-B
# 44  238  e20181651            Neom Nich    M        GRU  I5-WRI-B
# 45  111    sreylam                Admin  NaN        NaN   Sreylam
# 46   18  hakdaneth                  HAK    F        GRU    Daneth
# 47  253  e20160587       Seang Sotheany    M        GRU  I5-WRI-B
# 48  215  e20160150        Hean Kongheng    M        GRU  I5-WRI-A
# 49  237  e20160419           Nay Sophat    M        GRU  I5-WRI-B
# 50  204  e20160004             An Oudom    M        GRU  I5-WRI-A
# 51  211  e20160138          Hab Sopheak    M        GRU  I5-WRI-A
# 52  256  e20160653        Sorin Lykeang    F        GRU  I5-WRI-B
# 53  212  e20160146           Harn Norak    M        GRU  I5-WRI-A
# 54  258  e20160671           Sreang Mom    F        GRU  I5-WRI-B
# 55  267  e20150744            Tho Borin    M        GRU  I5-WRI-B
# 56  225  e20160239    KHANNRA Chhaiyuth    M        GRU  I5-WRI-A
# 57  236  e20160386        Men Keo Ratha    M        GRU  I5-WRI-B
# 58  266  e20160828            Yet Tokyo    M        GRU  I5-WRI-B
# 59  247  e20160496    Phoeun So Phanith    M        GRU  I5-WRI-B
#
#                       Course Name Module Name  State      Completion Date
# 0   Climate Change and Adaptation    resource      1  2020-10-13 15:40:51
# 1   Climate Change and Adaptation    resource      1  2020-10-20 13:05:44
# 2   Climate Change and Adaptation    resource      1  2020-10-20 13:05:58
# 3   Climate Change and Adaptation    resource      1  2020-10-20 13:20:57
# 4   Climate Change and Adaptation    resource      1  2020-10-20 13:23:38
# 5   Climate Change and Adaptation    resource      1  2020-10-20 13:32:35
# 6   Climate Change and Adaptation    resource      1  2020-10-20 13:38:38
# 7   Climate Change and Adaptation    resource      1  2020-10-20 13:39:29
# 8   Climate Change and Adaptation    resource      1  2020-10-20 13:48:23
# 9   Climate Change and Adaptation    resource      1  2020-10-20 15:31:12
# 10  Climate Change and Adaptation    resource      1  2020-10-20 15:56:02
# 11  Climate Change and Adaptation    resource      1  2020-10-21 21:22:04
# 12  Climate Change and Adaptation    resource      1  2020-10-22 08:38:19
# 13  Climate Change and Adaptation    resource      1  2020-10-22 19:23:40
# 14  Climate Change and Adaptation    resource      1  2020-10-20 15:34:30
# 15  Climate Change and Adaptation    resource      1  2020-10-20 12:47:41
# 16  Climate Change and Adaptation    resource      1  2020-10-20 12:48:45
# 17  Climate Change and Adaptation    resource      1  2020-10-20 08:04:58
# 18  Climate Change and Adaptation    resource      1  2020-10-19 20:01:49
# 19  Climate Change and Adaptation    resource      1  2020-10-17 14:13:34
# 20  Climate Change and Adaptation    resource      1  2020-10-15 16:51:27
# 21  Climate Change and Adaptation    resource      1  2020-10-16 14:06:29
# 22  Climate Change and Adaptation    resource      1  2020-10-15 13:27:25
# 23  Climate Change and Adaptation    resource      1  2020-10-15 01:15:06
# 24  Climate Change and Adaptation    resource      1  2020-10-14 00:22:42
# 25  Climate Change and Adaptation    resource      1  2020-10-13 15:55:56
# 26  Climate Change and Adaptation    resource      1  2020-10-20 13:38:30
# 27  Climate Change and Adaptation    resource      1  2020-10-17 11:39:56
# 28  Climate Change and Adaptation    resource      1  2020-10-20 11:38:31
# 29  Climate Change and Adaptation    resource      1  2020-10-20 14:00:07
# 30  Climate Change and Adaptation    resource      1  2020-10-13 10:38:52
# 31  Climate Change and Adaptation    resource      1  2020-10-15 13:59:53
# 32  Climate Change and Adaptation    resource      1  2020-10-16 16:50:54
# 33  Climate Change and Adaptation    resource      1  2020-10-16 19:05:26
# 34  Climate Change and Adaptation    resource      1  2020-10-17 12:34:58
# 35  Climate Change and Adaptation    resource      1  2020-10-20 11:00:15
# 36  Climate Change and Adaptation    resource      1  2020-10-20 12:48:56
# 37  Climate Change and Adaptation    resource      1  2020-10-20 12:58:15
# 38  Climate Change and Adaptation    resource      1  2020-10-20 13:10:40
# 39  Climate Change and Adaptation    resource      1  2020-10-20 14:21:45
# 40  Climate Change and Adaptation    resource      1  2020-10-20 14:47:57
# 41  Climate Change and Adaptation    resource      1  2020-10-20 15:59:46
# 42  Climate Change and Adaptation    resource      1  2020-10-21 14:17:24
# 43  Climate Change and Adaptation    resource      1  2020-10-22 20:45:02
# 44  Climate Change and Adaptation    resource      1  2020-10-20 13:38:19
# 45  Climate Change and Adaptation    resource      1  2020-10-12 12:51:20
# 46  Climate Change and Adaptation    resource      1  2020-10-13 10:38:55
# 47  Climate Change and Adaptation    resource      1  2020-10-13 13:18:44
# 48  Climate Change and Adaptation    resource      1  2020-10-13 13:23:31
# 49  Climate Change and Adaptation    resource      1  2020-10-13 13:29:41
# 50  Climate Change and Adaptation    resource      1  2020-10-13 13:30:47
# 51  Climate Change and Adaptation    resource      1  2020-10-13 13:31:13
# 52  Climate Change and Adaptation    resource      1  2020-10-13 13:39:01
# 53  Climate Change and Adaptation    resource      1  2020-10-13 13:39:52
# 54  Climate Change and Adaptation    resource      1  2020-10-13 13:41:45
# 55  Climate Change and Adaptation    resource      1  2020-10-13 13:43:18
# 56  Climate Change and Adaptation    resource      1  2020-10-13 13:55:17
# 57  Climate Change and Adaptation    resource      1  2020-10-13 13:57:50
# 58  Climate Change and Adaptation    resource      1  2020-10-13 14:01:29
# 59  Climate Change and Adaptation    resource      1  2020-10-13 14:17:15

# %%
def courseStudent(md,course):
    if course == 'All':
        progress = md[(md['State'] == 1)]
    else:
        progress = md[(md['State'] == 1) & (md['Course Name'] == course)]
    # pg = progress.groupby(['Student Name','Course Name']).count()
    # print(pg[['ID']])
    arr = []
    for i in range(0, len(progress)):
        name = progress.iloc[i][2]
        sex =  progress.iloc[i][3]
        course = progress.iloc[i][6]

        completed = progress[progress['Student Name'] == name].count()


        if [name, sex,course, completed[0]] not in arr:
            arr.insert(i, [name, sex, course, completed[0]])


    pro = pd.DataFrame(arr, columns = ['Student Name', 'Sex', 'Course', 'Completed'])
    pro.sort_values(by=['Student Name'], inplace=True)
    return pro
md = df1.rename(columns={'userid':'ID', 'username': 'Username', 'firstname':'Student Name', 'phone1':'Sex', 'department':'Department', 'lastname':'Group', 'courseName':'Course Name', 'moduleName':'Module Name', 'completionstate': 'State', 'CompletionDate':'Completion Date'})
 
courseStudent(md, 'Software Engineering')
# Out:
#            Student Name Sex                Course  Completed
# 26      ANG MENGCHHUONG   M  Software Engineering          2
# 27          CHAN BUNNET   M  Software Engineering          1
# 28          CHEA DARIKA   F  Software Engineering          3
# 6        HENG NGOUN HAK   M  Software Engineering          2
# 7      HENG SOVANPISETH   M  Software Engineering          2
# 5       HOUR CHAN PISEY   M  Software Engineering          2
# 11       KEO KANBUTHICA   M  Software Engineering          1
# 1            KUOCH NARO   M  Software Engineering          3
# 15       LEAN CHHORNORN   M  Software Engineering          2
# 0         LEANG KIMHENG   M  Software Engineering          3
# 20          LIM SAMPONG   M  Software Engineering          1
# 25           LIM SOVANN   M  Software Engineering          1
# 16         LIV BUNTHORN   M  Software Engineering          2
# 17          MENG SOPHEA   M  Software Engineering          1
# 24           OL PHEARUN   M  Software Engineering          2
# 9         PHOEM PHANITH   M  Software Engineering          1
# 13  RITH CHAN VIRAKBOTH   M  Software Engineering          3
# 12      SAM SOVANSOUKEA   M  Software Engineering          1
# 23           SOK VANNAL   M  Software Engineering          1
# 3            SREY BOTIN   M  Software Engineering          3
# 4     THARY PUTTHEARITH   M  Software Engineering          2
# 10          THO THARATH   M  Software Engineering          1
# 19     TIENG PANHA POUN   F  Software Engineering          1
# 18        TOB SOPHANITH   M  Software Engineering          2
# 2            TRY SREYNA   F  Software Engineering          5
# 21            UN LYKONG   F  Software Engineering          2
# 14             VIN ILEN   F  Software Engineering          2
# 8            VUTHY DARA   M  Software Engineering          2
# 22           YEAN SEYHA   M  Software Engineering          3

# %%
# a = courseStudent(md, 'Software Engineering')
# b = a[['Sex']].value_counts()
# b[0]
# b[1]
# Out:
# 24

# %%
g2 = sns.countplot(x="Sex", data=pro)
for p in g2.patches:
        percentage = '{:.0f}'.format(p.get_height())
        x = p.get_x() + p.get_width()/2 + 0.02
        y = (p.get_y() + p.get_height()) + 0.2
        g2.annotate(percentage, (x, y))
g2
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=penguins, kind="bar",
    y="species", x="body_mass_g", hue="sex",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")
g.legend.set_title("")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
md.groupby(['Department','Course Name']).size().unstack().plot(kind='barh',stacked=True)
# Out:
# <AxesSubplot:ylabel='Department'>

# %%
df1[(df1['courseName'] == 'Geodesy and Topography')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-c13681bf3aed> in <module>
# ----> 1 df1[(df1['courseName'] == 'Geodesy and Topography').unique()]
#
# c:\users\virak\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2895         # Do we have a (boolean) 1d indexer?
#    2896         if com.is_bool_indexer(key):
# -> 2897             return self._getitem_bool_array(key)
#    2898
#    2899         # We are left with two options: a single key, and a collection of keys,
#
# c:\users\virak\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2941             )
#    2942         elif len(key) != len(self.index):
# -> 2943             raise ValueError(
#    2944                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    2945             )
#
# ValueError: Item wrong length 2 instead of 792.

# %% [markdown]
# # I. Course

# %% [markdown]
# 1. Show all course and all students in each course

# %%
import pandas as pd
md = pd.read_csv('moodleitcdata.csv')

cond = md.groupby(['courseName','firstname']).count()
cond
# Out:
#                                                  userid  username  phone1  \
# courseName                    firstname
# Climate Change and Adaptation Admin                   1         1       0
#                               An Oudom                1         1       1
#                               Chaing Seyhakmony       2         2       2
#                               Chea Hormey             1         1       1
#                               Dorn Da                 1         1       1
# ...                                                 ...       ...     ...
# Topographic Surveying         DOU LICHUER             1         1       1
#                               DOUNG REAKSA            3         3       3
#                               HEL HORNG               1         1       1
#                               PEANG SITHIRONG         1         1       1
#                               TESTING                 2         2       2
#
#                                                  department  lastname  \
# courseName                    firstname
# Climate Change and Adaptation Admin                       0         1
#                               An Oudom                    1         1
#                               Chaing Seyhakmony           2         2
#                               Chea Hormey                 1         1
#                               Dorn Da                     1         1
# ...                                                     ...       ...
# Topographic Surveying         DOU LICHUER                 1         1
#                               DOUNG REAKSA                3         3
#                               HEL HORNG                   1         1
#                               PEANG SITHIRONG             1         1
#                               TESTING                     2         2
#
#                                                  moduleName  completionstate  \
# courseName                    firstname
# Climate Change and Adaptation Admin                       1                1
#                               An Oudom                    1                1
#                               Chaing Seyhakmony           2                2
#                               Chea Hormey                 1                1
#                               Dorn Da                     1                1
# ...                                                     ...              ...
# Topographic Surveying         DOU LICHUER                 1                1
#                               DOUNG REAKSA                3                3
#                               HEL HORNG                   1                1
#                               PEANG SITHIRONG             1                1
#                               TESTING                     2                2
#
#                                                  CompletionDate
# courseName                    firstname
# Climate Change and Adaptation Admin                           1
#                               An Oudom                        1
#                               Chaing Seyhakmony               2
#                               Chea Hormey                     1
#                               Dorn Da                         1
# ...                                                         ...
# Topographic Surveying         DOU LICHUER                     1
#                               DOUNG REAKSA                    3
#                               HEL HORNG                       1
#                               PEANG SITHIRONG                 1
#                               TESTING                         2
#
# [431 rows x 8 columns]

# %% [markdown]
# 2. Give a summary info for each course (type of course material scorm or html/resource?, how many students enrolled? how many female and male?, how many are active during time t1 to t2?)

# %%
import pandas as pd
md =pd.read_csv('moodleitcdata.csv')
md = md.rename(columns={'userid':'ID', 'username': 'Username', 'firstname':'Firstname', 'phone1':'Sex', 'department':'Department', 'lastname':'Group', 'courseName':'Course Name', 'moduleName':'Module Name', 'completionstate': 'Completion State', 'CompletionDate':'Completion Date'})
    
start_date = '2020-10-22'
end_date = '2020-12-01'

md = md[(md['Completion Date'] >= start_date ) & (md['Completion Date'] <= end_date) ]

cond1=md.groupby(['Course Name','Module Name','Sex']).count()
cond1
# Out:
#                                                                   ID  \
# Course Name                                      Module Name Sex
# Climate Change and Adaptation                    resource    M     3
# Database Analysis and Design                     scorm       F     3
#                                                              M    27
# Food Microbiology                                scorm       F     1
# Geodesy and Topography                           resource    M     2
# Geographic Information System and Remote Sensing scorm       F     1
#                                                              M     9
# Image Processing                                 resource    M     1
#                                                  scorm       M     1
# Introduction to Computer Science                 scorm       M     1
# Software Engineering                             scorm       M     1
# Strength of Material                             resource    F     2
#                                                              M    10
# Topographic Surveying                            scorm       F     1
#                                                              M     9
#
#                                                                   Username  \
# Course Name                                      Module Name Sex
# Climate Change and Adaptation                    resource    M           3
# Database Analysis and Design                     scorm       F           3
#                                                              M          27
# Food Microbiology                                scorm       F           1
# Geodesy and Topography                           resource    M           2
# Geographic Information System and Remote Sensing scorm       F           1
#                                                              M           9
# Image Processing                                 resource    M           1
#                                                  scorm       M           1
# Introduction to Computer Science                 scorm       M           1
# Software Engineering                             scorm       M           1
# Strength of Material                             resource    F           2
#                                                              M          10
# Topographic Surveying                            scorm       F           1
#                                                              M           9
#
#                                                                   Firstname  \
# Course Name                                      Module Name Sex
# Climate Change and Adaptation                    resource    M            3
# Database Analysis and Design                     scorm       F            3
#                                                              M           27
# Food Microbiology                                scorm       F            1
# Geodesy and Topography                           resource    M            2
# Geographic Information System and Remote Sensing scorm       F            1
#                                                              M            9
# Image Processing                                 resource    M            1
#                                                  scorm       M            1
# Introduction to Computer Science                 scorm       M            1
# Software Engineering                             scorm       M            1
# Strength of Material                             resource    F            2
#                                                              M           10
# Topographic Surveying                            scorm       F            1
#                                                              M            9
#
#                                                                   Department  \
# Course Name                                      Module Name Sex
# Climate Change and Adaptation                    resource    M             3
# Database Analysis and Design                     scorm       F             3
#                                                              M            27
# Food Microbiology                                scorm       F             1
# Geodesy and Topography                           resource    M             2
# Geographic Information System and Remote Sensing scorm       F             1
#                                                              M             9
# Image Processing                                 resource    M             1
#                                                  scorm       M             1
# Introduction to Computer Science                 scorm       M             1
# Software Engineering                             scorm       M             1
# Strength of Material                             resource    F             2
#                                                              M            10
# Topographic Surveying                            scorm       F             1
#                                                              M             9
#
#                                                                   Group  \
# Course Name                                      Module Name Sex
# Climate Change and Adaptation                    resource    M        3
# Database Analysis and Design                     scorm       F        3
#                                                              M       27
# Food Microbiology                                scorm       F        1
# Geodesy and Topography                           resource    M        2
# Geographic Information System and Remote Sensing scorm       F        1
#                                                              M        9
# Image Processing                                 resource    M        1
#                                                  scorm       M        1
# Introduction to Computer Science                 scorm       M        1
# Software Engineering                             scorm       M        1
# Strength of Material                             resource    F        2
#                                                              M       10
# Topographic Surveying                            scorm       F        1
#                                                              M        9
#
#                                                                   Completion State  \
# Course Name                                      Module Name Sex
# Climate Change and Adaptation                    resource    M                   3
# Database Analysis and Design                     scorm       F                   3
#                                                              M                  27
# Food Microbiology                                scorm       F                   1
# Geodesy and Topography                           resource    M                   2
# Geographic Information System and Remote Sensing scorm       F                   1
#                                                              M                   9
# Image Processing                                 resource    M                   1
#                                                  scorm       M                   1
# Introduction to Computer Science                 scorm       M                   1
# Software Engineering                             scorm       M                   1
# Strength of Material                             resource    F                   2
#                                                              M                  10
# Topographic Surveying                            scorm       F                   1
#                                                              M                   9
#
#                                                                   Completion Date
# Course Name                                      Module Name Sex
# Climate Change and Adaptation                    resource    M                  3
# Database Analysis and Design                     scorm       F                  3
#                                                              M                 27
# Food Microbiology                                scorm       F                  1
# Geodesy and Topography                           resource    M                  2
# Geographic Information System and Remote Sensing scorm       F                  1
#                                                              M                  9
# Image Processing                                 resource    M                  1
#                                                  scorm       M                  1
# Introduction to Computer Science                 scorm       M                  1
# Software Engineering                             scorm       M                  1
# Strength of Material                             resource    F                  2
#                                                              M                 10
# Topographic Surveying                            scorm       F                  1
#                                                              M                  9

# %%
# Option 2
import pandas as pd
md =pd.read_csv('moodleitcdata.csv')
md = md.rename(columns={'userid':'ID', 'username': 'Username', 'firstname':'Firstname', 'phone1':'Sex', 'department':'Department', 'lastname':'Group', 'courseName':'Course Name', 'moduleName':'Module Name', 'completionstate': 'Completion State', 'CompletionDate':'Completion Date'})
    
start_date = '2020-10-22'
end_date = '2020-12-01'

df = []
for i in range(0, len(md)):
    course = md.iloc[i][6]
    moduleName = md.iloc[i][7]
    male_student = md[ (md['Sex'] == 'M') & (md['Course Name'] == course) & (md['Completion Date'] >= str(start_date)) & (md['Completion Date'] <= str(end_date))]
    female_student = md[ (md['Sex'] == 'F') & (md['Course Name'] == course) & (md['Completion Date'] >= str(start_date)) & (md['Completion Date'] <= str(end_date)) ]

    m = male_student['ID'].count()
    f = female_student['ID'].count()

    if [course,moduleName,m,f] not in df:
        df.insert(i, [course,moduleName,m,f])


df = pd.DataFrame(df, columns = ['Course', 'Module Name', 'Male', 'Female'])
df
# Out:
#                                               Course Module Name  Male  Female
# 0                      Climate Change and Adaptation    resource     3       0
# 1                                         Cover Crop       scorm     0       0
# 2                       Database Analysis and Design       scorm    27       3
# 3                              Environmental Geology       scorm     0       0
# 4                                  Food Microbiology       scorm     0       1
# 5                             Geodesy and Topography    resource     2       0
# 6   Geographic Information System and Remote Sensing       scorm     9       1
# 7                                   Image Processing    resource     2       0
# 8                                   Image Processing       scorm     2       0
# 9                   Introduction to Computer Science       scorm     1       0
# 10                       Natural Language Processing    resource     0       0
# 11                              Software Engineering       scorm     1       0
# 12                              Strength of Material    resource    10       2
# 13                             Topographic Surveying       scorm     9       1

# %%
md[md['Sex'] == 'F'].sum()[0]
# Out:
# 3221

# %%
import raccoon as rc

# %%
df1 = pd.read_csv('moodleitcdata.csv')
df = df1.rename(columns={'userid':'userid', 'username': 'ID', 'firstname':'Student Name', 'phone1':'Sex', 'department':'Department', 'lastname':'Group', 'courseName':'Course Name', 'moduleName':'Module Name', 'completionstate': 'State', 'CompletionDate':'Completion Date'})
md = df

# %% [markdown]
# 3. Show students learning progress of a selected course during a period of time (during startDate and endDate filter)

# %%
startDate = '2020-09-12 00:00:00'
endDate = '2020-12-20 00:00:00'
course = 'Image Processing'
progress = md[(md['State'] == 1) & (md['Completion Date'] >= startDate) & (md['Completion Date'] <= endDate) & (md['Course Name'] == course)]
# pg = progress.groupby(['Firstname','Course Name']).count()
# pg[['ID']]
# print(progress)
arr = []
for i in range(0, len(progress)):
    id = progress.iloc[i][1]
    name = progress.iloc[i][2]
    sex =  progress.iloc[i][3]
    course = progress.iloc[i][6]
    
    completed = progress[progress['Student Name'] == name].count()


    if [id, name, sex,course, completed[0]] not in arr:
        arr.insert(i, [id, name, sex, course, completed[0]])
        
arr
df = pd.DataFrame(arr, columns = ['ID', 'Student Name', 'Sex', 'Course', 'Completed'])
df
# Out:
#      userid         ID    Student Name Sex Department   Group  \
# 513     332  e20160584      SEAM VIRAK   M        GIC  I5-GIC
# 514     329  e20150543   PORK CHANCHEN   M        GIC  I5-GIC
# 515     332  e20160584      SEAM VIRAK   M        GIC  I5-GIC
# 516     325  e20160488       PHAT MADY   M        GIC  I5-GIC
# 517     328  e20160514  POENG KOK THAY   M        GIC  I5-GIC
# 518     332  e20160584      SEAM VIRAK   M        GIC  I5-GIC
# 519     332  e20160584      SEAM VIRAK   M        GIC  I5-GIC
# 520     318  e20160148       HE PISETH   M        GIC  I5-GIC
#
#           Course Name Module Name  State      Completion Date
# 513  Image Processing    resource      1  2020-10-22 10:44:55
# 514  Image Processing    resource      1  2020-10-13 09:19:02
# 515  Image Processing    resource      1  2020-10-12 22:47:10
# 516  Image Processing       scorm      1  2020-10-13 10:27:43
# 517  Image Processing       scorm      1  2020-10-19 22:51:22
# 518  Image Processing       scorm      1  2020-10-22 10:36:39
# 519  Image Processing       scorm      1  2020-10-12 22:44:10
# 520  Image Processing       scorm      1  2020-10-13 10:52:47
#           ID    Student Name Sex            Course  Completed
# 0  e20160584      SEAM VIRAK   M  Image Processing          4
# 1  e20150543   PORK CHANCHEN   M  Image Processing          1
# 2  e20160488       PHAT MADY   M  Image Processing          1
# 3  e20160514  POENG KOK THAY   M  Image Processing          1
# 4  e20160148       HE PISETH   M  Image Processing          1

# %%
df1 = pd.read_csv('moodleitcdata.csv')
df = df1.rename(columns={'userid':'userid', 'username': 'ID', 'firstname':'Student Name', 'phone1':'Sex', 'department':'Department', 'lastname':'Group', 'courseName':'Course Name', 'moduleName':'Module Name', 'completionstate': 'State', 'CompletionDate':'Completion Date'})
md = df

from datetime import timedelta

startDate = str(today - timedelta(14))
endDate = str(datetime.date.today())

# startDate = '2020-09-12 00:00:00'
# endDate = '2020-12-20 00:00:00'
course = 'Image Processing'
progress = md[(md['State'] == 1) & (md['Completion Date'] >= startDate) & (md['Completion Date'] <= endDate) & (md['Course Name'] == course)]

arr = []
for i in range(0, len(progress)):
    id = progress.iloc[i][1]
    name = progress.iloc[i][2]
    sex =  progress.iloc[i][3]
    course = progress.iloc[i][6]
    
    completed = progress[progress['Student Name'] == name].count()


    if [id, name, sex,course, completed[0]] not in arr:
        arr.insert(i, [id, name, sex, course, completed[0]])
        
arr
df = pd.DataFrame(arr, columns = ['ID', 'Student Name', 'Sex', 'Course', 'Completed'])
df
# Out:
# 2021-01-22
# Empty DataFrame
# Columns: [ID, Student Name, Sex, Course, Completed]
# Index: []

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

md = pd.read_csv('moodleitcdata.csv')
md = md.rename(columns={'userid':'ID', 'username': 'Student ID', 'firstname':'Student Name', 'phone1':'Sex', 'department':'Department', 'lastname':'Group', 'courseName':'Course Name', 'moduleName':'Module Name', 'completionstate': 'Completion State', 'CompletionDate':'Completion Date'})
md['CN']=md['Course Name'].map({'Climate Change and Adaptation':'CCA', 'Cover Crop':'CC',\
       'Database Analysis and Design':'DAD', 'Environmental Geology':'EG',\
       'Food Microbiology':'FM', 'Geodesy and Topography':'GT',\
       'Geographic Information System and Remote Sensing':'GISRS',\
       'Image Processing':'IM', 'Introduction to Computer Science':'ICS',\
       'Natural Language Processing':'NLP', 'Software Engineering':'SE',\
       'Strength of Material':'SM', 'Topographic Surveying':'TS'})
# plt.figure(figsize=(6,12), dpi=250)
g = sns.countplot( y='CN',hue = 'Sex', data = md)
for p in g.patches:
        percentage = '{:.0f}'.format(p.get_width())
        x = p.get_x() + p.get_width() + 0.02
        y = (p.get_y() + p.get_height()/2) + 0.15
        g.annotate(percentage, (x, y))
        
plt.title("Number of student for each course")
plt.xlabel('Number of students')
plt.ylabel('Courses')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

md = pd.read_csv('moodleitcdata.csv')
md = md.rename(columns={'userid':'ID', 'username': 'Student ID', 'firstname':'Student Name', 'phone1':'Sex', 'department':'Department', 'lastname':'Group', 'courseName':'Course Name', 'moduleName':'Module Name', 'completionstate': 'Completion State', 'CompletionDate':'Completion Date'})
g = sns.countplot( y='Department',hue = 'Sex', data = md)
for p in g.patches:
        percentage = '{:.0f}'.format(p.get_width())
        x = p.get_x() + p.get_width() + 0.02
        y = (p.get_y() + p.get_height()/2) + 0.15
        g.annotate(percentage, (x, y))
        
plt.title("Number of student for each course")
plt.xlabel('Number of students')
plt.ylabel('DEPARTMENT')
plt.show()

# %% [markdown]
# 4. How many students are active during the time t1 to t2. (t1 and t2 are date timestamp) (active is basically mean they are access to learn the course. can be validated via the completionState column in dataset)

# %%
md = pd.read_csv('moodleitcdata.csv')

t1 = '2020-10-12 00:00:00'
t2 = '2020-11-20 00:00:00'
state = 1

activeStudent = md[(md['CompletionDate'] >= t1) & (md['CompletionDate'] <= t2) & (md['completionstate'] == state)]
# getActive['username']
studentNum = activeStudent.groupby(['courseName']).count()
studentNum
# Out:
#                                                   userid  username  firstname  \
# courseName
# Climate Change and Adaptation                         60        60         60
# Cover Crop                                             1         1          1
# Database Analysis and Design                         155       155        155
# Environmental Geology                                  9         9          9
# Food Microbiology                                    123       123        123
# Geodesy and Topography                                78        78         78
# Geographic Information System and Remote Sensing      87        87         87
# Image Processing                                       8         8          8
# Introduction to Computer Science                       5         5          5
# Natural Language Processing                           28        28         28
# Software Engineering                                  57        57         57
# Strength of Material                                 124       124        124
# Topographic Surveying                                 10        10         10
#
#                                                   phone1  department  \
# courseName
# Climate Change and Adaptation                         59          59
# Cover Crop                                             0           0
# Database Analysis and Design                         155         155
# Environmental Geology                                  9           9
# Food Microbiology                                    123         123
# Geodesy and Topography                                78          78
# Geographic Information System and Remote Sensing      87          87
# Image Processing                                       8           8
# Introduction to Computer Science                       5           5
# Natural Language Processing                           26          26
# Software Engineering                                  57          57
# Strength of Material                                 124         124
# Topographic Surveying                                 10          10
#
#                                                   lastname  moduleName  \
# courseName
# Climate Change and Adaptation                           60          60
# Cover Crop                                               1           1
# Database Analysis and Design                           155         155
# Environmental Geology                                    9           9
# Food Microbiology                                      123         123
# Geodesy and Topography                                  78          78
# Geographic Information System and Remote Sensing        87          87
# Image Processing                                         8           8
# Introduction to Computer Science                         5           5
# Natural Language Processing                             28          28
# Software Engineering                                    57          57
# Strength of Material                                   124         124
# Topographic Surveying                                   10          10
#
#                                                   completionstate  \
# courseName
# Climate Change and Adaptation                                  60
# Cover Crop                                                      1
# Database Analysis and Design                                  155
# Environmental Geology                                           9
# Food Microbiology                                             123
# Geodesy and Topography                                         78
# Geographic Information System and Remote Sensing               87
# Image Processing                                                8
# Introduction to Computer Science                                5
# Natural Language Processing                                    28
# Software Engineering                                           57
# Strength of Material                                          124
# Topographic Surveying                                          10
#
#                                                   CompletionDate
# courseName
# Climate Change and Adaptation                                 60
# Cover Crop                                                     1
# Database Analysis and Design                                 155
# Environmental Geology                                          9
# Food Microbiology                                            123
# Geodesy and Topography                                        78
# Geographic Information System and Remote Sensing              87
# Image Processing                                               8
# Introduction to Computer Science                               5
# Natural Language Processing                                   28
# Software Engineering                                          57
# Strength of Material                                         124
# Topographic Surveying                                         10

# %% [markdown]
# 5. Show a summary of a course (how many students enrolled?, how many males and females? how many of them are currently active within the past 2 weeks?, ....)

# %% [markdown]
# 6. List all courses in each department order by academic year and student level year.

# %% [markdown]
# 7. Give a summary info for each department in a specified academic year (how many courses? how many students in each course, how many females and males? how many of them are currently active)

# %%
import pandas as pd
from datetime import datetime, timedelta

md =pd.read_csv('moodleitcdata.csv')
md = md.rename(columns={'userid':'ID', 'username': 'Username', 'firstname':'Firstname', 'phone1':'Sex', 'department':'Department', 'lastname':'Group', 'courseName':'Course Name', 'moduleName':'Module Name', 'completionstate': 'Completion State', 'CompletionDate':'Completion Date'})
    
md = md[md['Department'] == 'GIC'] #dep GIC
md = md[md['Group'] == 'I5-GIC'] #Year 5

N = 14 #last 14 day
date_N_days_ago = datetime.now() - timedelta(days=N)
# start_date = str(date_N_days_ago)
# end_date = datetime.now()

#test
start_date = '2020-10-22'
end_date = '2020-12-01'

df = []
for i in range(0, len(md)):
    course = md.iloc[i][6]
    moduleName = md.iloc[i][7]
    c_male_student = md[ (md['Sex'] == 'M') & (md['Course Name'] == course) & (md['Completion Date'] >= str(start_date)) & (md['Completion Date'] <= str(end_date))]
    c_female_student = md[ (md['Sex'] == 'F') & (md['Course Name'] == course) & (md['Completion Date'] >= str(start_date)) & (md['Completion Date'] <= str(end_date)) ]
    male_student = md[ (md['Sex'] == 'M') & (md['Course Name'] == course)]
    female_student = md[ (md['Sex'] == 'F') & (md['Course Name'] == course)]

    m = male_student['ID'].count()
    f = female_student['ID'].count()
    c_m = c_male_student['ID'].count()
    c_f = c_female_student['ID'].count()
    
    active_student = c_m + c_f

    if [course,moduleName,m,f,active_student] not in df:
        df.insert(i, [course,moduleName,m,f,active_student])


df = pd.DataFrame(df, columns = ['Course', 'Module Name', 'Male', 'Female', 'Active Student'])
df['All enroll'] = df['Male'] + df['Female']
df
# Out:
#                         Course Module Name  Male  Female  Active Student  \
# 0             Image Processing    resource     9       0               2
# 1             Image Processing       scorm     9       0               2
# 2  Natural Language Processing    resource    19       4               0
#
#    All enroll
# 0           9
# 1           9
# 2          23

# %% [markdown]
# # II. Student

# %% [markdown]
# 1. List all students in each year for each department

# %%
import pandas as pd
md = pd.read_csv('moodleitcdata.csv')
md[["DepartmentYear", "DepartmentName", "DepartmentGroup"]] = md["lastname"].str.split("-", expand = True)
md.groupby(['department', 'DepartmentYear','firstname']).count()
# Out:
#                                                userid  username  phone1  \
# department DepartmentYear firstname
# GCA        I4             CHIEB CHANTHOL            2         2       2
#                           Chann Kimsang             1         1       1
#                           Cheng Phallin             1         1       1
#                           Chhunteang Eanghay        1         1       1
#                           Chhuor Sochan Vimul       2         2       2
# ...                                               ...       ...     ...
# GRU        I5             Tai Sovandy               1         1       1
#                           Tho Borin                 2         2       2
#                           Veth Vathanachannbo       2         2       2
#                           Yao Thapiya               1         1       1
#                           Yet Tokyo                 4         4       4
#
#                                                lastname  courseName  \
# department DepartmentYear firstname
# GCA        I4             CHIEB CHANTHOL              2           2
#                           Chann Kimsang               1           1
#                           Cheng Phallin               1           1
#                           Chhunteang Eanghay          1           1
#                           Chhuor Sochan Vimul         2           2
# ...                                                 ...         ...
# GRU        I5             Tai Sovandy                 1           1
#                           Tho Borin                   2           2
#                           Veth Vathanachannbo         2           2
#                           Yao Thapiya                 1           1
#                           Yet Tokyo                   4           4
#
#                                                moduleName  completionstate  \
# department DepartmentYear firstname
# GCA        I4             CHIEB CHANTHOL                2                2
#                           Chann Kimsang                 1                1
#                           Cheng Phallin                 1                1
#                           Chhunteang Eanghay            1                1
#                           Chhuor Sochan Vimul           2                2
# ...                                                   ...              ...
# GRU        I5             Tai Sovandy                   1                1
#                           Tho Borin                     2                2
#                           Veth Vathanachannbo           2                2
#                           Yao Thapiya                   1                1
#                           Yet Tokyo                     4                4
#
#                                                CompletionDate  DepartmentName  \
# department DepartmentYear firstname
# GCA        I4             CHIEB CHANTHOL                    2               2
#                           Chann Kimsang                     1               1
#                           Cheng Phallin                     1               1
#                           Chhunteang Eanghay                1               1
#                           Chhuor Sochan Vimul               2               2
# ...                                                       ...             ...
# GRU        I5             Tai Sovandy                       1               1
#                           Tho Borin                         2               2
#                           Veth Vathanachannbo               2               2
#                           Yao Thapiya                       1               1
#                           Yet Tokyo                         4               4
#
#                                                DepartmentGroup
# department DepartmentYear firstname
# GCA        I4             CHIEB CHANTHOL                     0
#                           Chann Kimsang                      0
#                           Cheng Phallin                      0
#                           Chhunteang Eanghay                 0
#                           Chhuor Sochan Vimul                0
# ...                                                        ...
# GRU        I5             Tai Sovandy                        1
#                           Tho Borin                          2
#                           Veth Vathanachannbo                2
#                           Yao Thapiya                        1
#                           Yet Tokyo                          4
#
# [421 rows x 10 columns]

# %% [markdown]
# 2. Search all courses that a student enrolled in (e.g Dara)

# %%
studentName = 'KORN VANNAROTH'
df2 = md[md['firstname'] == studentName]
arr = df2['courseName'].unique()
arr
# Out:
# array(['Natural Language Processing', 'Image Processing'], dtype=object)

# %% [markdown]
# 3. List all courses that a student is in active access (active status if students access to lesson during the past 2 weeks)

# %%
import datetime
md = pd.read_csv('moodleitcdata.csv')
N = 14
active = datetime.date.today() - datetime.timedelta(days=N)
df1 = md[md['CompletionDate']<=str(active)]
df1['courseName'].unique()
# Out:
# array(['Climate Change and Adaptation', 'Cover Crop',
#        'Database Analysis and Design', 'Environmental Geology',
#        'Food Microbiology', 'Geodesy and Topography',
#        'Geographic Information System and Remote Sensing',
#        'Image Processing', 'Introduction to Computer Science',
#        'Natural Language Processing', 'Software Engineering',
#        'Strength of Material', 'Topographic Surveying'], dtype=object)

# %% [markdown]
# 4. Show learning progress (how many lessons finished?) of all students in each course in GIC department(can allow to select another department too)

# %%
md = pd.read_csv('moodleitcdata.csv')
md = md.rename(columns={'userid':'ID', 'username': 'Student ID', 'firstname':'Student Name', 'phone1':'Sex', 'department':'Department', 'lastname':'Group', 'courseName':'Course Name', 'moduleName':'Module Name', 'completionstate': 'Completion State', 'CompletionDate':'Completion Date'})

inp = input()
dep = ['GRU', 'GIC', 'GGG', 'GCA', 'GCI-GRU']
md1 = md[(md['Completion State']==1)&(md['Department']== inp)]
cond = md1.groupby(['Department','Course Name','ID','Student ID','Student Name','Sex','Group','Module Name']).count()
cond
# Out:
# GIC
#                                                                                              Completion State  \
# Department Course Name                  ID  Student ID Student Name  Sex Group  Module Name
# GIC        Database Analysis and Design 342 e20180005  AN SREYKHUOCH F   I3-GIC scorm                       2
#                                         344 e20180031  BROS TOCH     M   I3-GIC scorm                       1
#                                         346 e20180044  BUT DALIN     M   I3-GIC scorm                       2
#                                         347 e20180058  CHANN VICHEA  M   I3-GIC scorm                       2
#                                         349 e20180087  CHHAY LY AN   M   I3-GIC scorm                       3
# ...                                                                                                       ...
#            Software Engineering         306 e20170998  UN LYKONG     F   I4-GIC scorm                       2
#                                         307 e20171025  VIN ILEN      F   I4-GIC scorm                       2
#                                         309 e20171041  VUTHY DARA    M   I4-GIC scorm                       2
#                                         310 e20171052  YEAN SEYHA    M   I4-GIC scorm                       3
#            Topographic Surveying        849 test1      TESTING       M   test   scorm                       2
#
#                                                                                              Completion Date
# Department Course Name                  ID  Student ID Student Name  Sex Group  Module Name
# GIC        Database Analysis and Design 342 e20180005  AN SREYKHUOCH F   I3-GIC scorm                      2
#                                         344 e20180031  BROS TOCH     M   I3-GIC scorm                      1
#                                         346 e20180044  BUT DALIN     M   I3-GIC scorm                      2
#                                         347 e20180058  CHANN VICHEA  M   I3-GIC scorm                      2
#                                         349 e20180087  CHHAY LY AN   M   I3-GIC scorm                      3
# ...                                                                                                      ...
#            Software Engineering         306 e20170998  UN LYKONG     F   I4-GIC scorm                      2
#                                         307 e20171025  VIN ILEN      F   I4-GIC scorm                      2
#                                         309 e20171041  VUTHY DARA    M   I4-GIC scorm                      2
#                                         310 e20171052  YEAN SEYHA    M   I4-GIC scorm                      3
#            Topographic Surveying        849 test1      TESTING       M   test   scorm                      2
#
# [118 rows x 2 columns]

# %% [markdown]
# # III. Completion

# %% [markdown]
# 1. List all students who finished less than 5 lessons in each course.

# %%
import pandas as pd
md = pd.read_csv('moodleitcdata.csv')
md1 = md[md['completionstate']==1]
cond1 = md1.groupby(['userid','username','firstname','phone1','department','lastname','courseName','moduleName']).count()
cond1[cond1['completionstate']<5]
# Out:
#                                                                                                           completionstate  \
# userid username  firstname           phone1 department lastname courseName                    moduleName
# 18     hakdaneth HAK                 F      GRU        Daneth   Climate Change and Adaptation resource                  2
# 19     bouchanna BOU                 M      GIC        Channa   Natural Language Processing   resource                  1
# 32     e20170071 Cheng Phallin       F      GCA        I4-GCA   Food Microbiology             scorm                     1
# 36     e20191324 Chhunteang Eanghay  M      GCA        I4-GCA   Food Microbiology             scorm                     1
# 37     e20170132 Chhuor Sochan Vimul F      GCA        I4-GCA   Food Microbiology             scorm                     2
# ...                                                                                                                   ...
# 847    e20170965 THOU CHANRAT        F      GCA        I4-GCA   Food Microbiology             scorm                     1
# 849    test1     TESTING             M      GIC        test     Database Analysis and Design  scorm                     3
#                                                                 Topographic Surveying         scorm                     2
# 850    m030605   SIM Ratha           F      GCA        M1-GCA   Food Microbiology             scorm                     1
# 856    e20180289 HENG SOTHEAROTH     M      GRU        I3-A     Strength of Material          resource                  2
#
#                                                                                                           CompletionDate
# userid username  firstname           phone1 department lastname courseName                    moduleName
# 18     hakdaneth HAK                 F      GRU        Daneth   Climate Change and Adaptation resource                 2
# 19     bouchanna BOU                 M      GIC        Channa   Natural Language Processing   resource                 1
# 32     e20170071 Cheng Phallin       F      GCA        I4-GCA   Food Microbiology             scorm                    1
# 36     e20191324 Chhunteang Eanghay  M      GCA        I4-GCA   Food Microbiology             scorm                    1
# 37     e20170132 Chhuor Sochan Vimul F      GCA        I4-GCA   Food Microbiology             scorm                    2
# ...                                                                                                                  ...
# 847    e20170965 THOU CHANRAT        F      GCA        I4-GCA   Food Microbiology             scorm                    1
# 849    test1     TESTING             M      GIC        test     Database Analysis and Design  scorm                    3
#                                                                 Topographic Surveying         scorm                    2
# 850    m030605   SIM Ratha           F      GCA        M1-GCA   Food Microbiology             scorm                    1
# 856    e20180289 HENG SOTHEAROTH     M      GRU        I3-A     Strength of Material          resource                 2
#
# [418 rows x 2 columns]

# %% [markdown]
# 2. List all students who finished more than 5 lessons in each course.
# 3. List all students who finished more than 7 lessons in each course.
# 4. List all students who finished more than 10 lessons in each course.

# %% [markdown]
# 5. Give a summary of learning progress of students in each course (show students who finished (completionState is 1) more than 6 lessons)

# %%
import pandas as pd
md = pd.read_csv('moodleitcdata.csv')
md1 = md[md['completionstate']==1]
cond1 = md1.groupby(['userid','username','firstname','phone1','department','lastname','courseName','moduleName']).count()
cond1[cond1['completionstate']<5]
# Out:
#                                                                                                           completionstate  \
# userid username  firstname           phone1 department lastname courseName                    moduleName
# 18     hakdaneth HAK                 F      GRU        Daneth   Climate Change and Adaptation resource                  2
# 19     bouchanna BOU                 M      GIC        Channa   Natural Language Processing   resource                  1
# 32     e20170071 Cheng Phallin       F      GCA        I4-GCA   Food Microbiology             scorm                     1
# 36     e20191324 Chhunteang Eanghay  M      GCA        I4-GCA   Food Microbiology             scorm                     1
# 37     e20170132 Chhuor Sochan Vimul F      GCA        I4-GCA   Food Microbiology             scorm                     2
# ...                                                                                                                   ...
# 847    e20170965 THOU CHANRAT        F      GCA        I4-GCA   Food Microbiology             scorm                     1
# 849    test1     TESTING             M      GIC        test     Database Analysis and Design  scorm                     3
#                                                                 Topographic Surveying         scorm                     2
# 850    m030605   SIM Ratha           F      GCA        M1-GCA   Food Microbiology             scorm                     1
# 856    e20180289 HENG SOTHEAROTH     M      GRU        I3-A     Strength of Material          resource                  2
#
#                                                                                                           CompletionDate
# userid username  firstname           phone1 department lastname courseName                    moduleName
# 18     hakdaneth HAK                 F      GRU        Daneth   Climate Change and Adaptation resource                 2
# 19     bouchanna BOU                 M      GIC        Channa   Natural Language Processing   resource                 1
# 32     e20170071 Cheng Phallin       F      GCA        I4-GCA   Food Microbiology             scorm                    1
# 36     e20191324 Chhunteang Eanghay  M      GCA        I4-GCA   Food Microbiology             scorm                    1
# 37     e20170132 Chhuor Sochan Vimul F      GCA        I4-GCA   Food Microbiology             scorm                    2
# ...                                                                                                                  ...
# 847    e20170965 THOU CHANRAT        F      GCA        I4-GCA   Food Microbiology             scorm                    1
# 849    test1     TESTING             M      GIC        test     Database Analysis and Design  scorm                    3
#                                                                 Topographic Surveying         scorm                    2
# 850    m030605   SIM Ratha           F      GCA        M1-GCA   Food Microbiology             scorm                    1
# 856    e20180289 HENG SOTHEAROTH     M      GRU        I3-A     Strength of Material          resource                 2
#
# [418 rows x 2 columns]

# %% [markdown]
# 6. Give a summary of learning progress of students in each course (show students who finished 6<lesson<=10)

# %%
import pandas as pd
md = pd.read_csv('moodleitcdata.csv')
md1 = md[md['completionstate']==1]
cond1 = md1.groupby(['courseName','userid','username','firstname','phone1','department','lastname','moduleName']).count()
cond1[(cond1['completionstate']>6)&(cond1['completionstate']<=10)]
# Out:
#                                                                                          completionstate  \
# courseName             userid username  firstname phone1 department lastname moduleName
# Geodesy and Topography 745    e20180807 PONG POV  M      GGG        I3-GGG   resource                  9
#
#                                                                                          CompletionDate
# courseName             userid username  firstname phone1 department lastname moduleName
# Geodesy and Topography 745    e20180807 PONG POV  M      GGG        I3-GGG   resource                 9

# %% [markdown]
# 7. Give a summary of learning progress of students in each course (show students who finished lesson>10)

# %%
import pandas as pd
md = pd.read_csv('moodleitcdata.csv')
md1 = md[md['completionstate']==1]
cond1 = md1.groupby(['courseName','userid','username','firstname','phone1','department','lastname','moduleName']).count()
cond1[(cond1['completionstate']>10)]
# Out:
#                                                                                                                    completionstate  \
# courseName                                       userid username  firstname phone1 department lastname moduleName
# Geographic Information System and Remote Sensing 134    e20170315 Kao Lyhov M      GRU        I4-WRI-A scorm                    13
#
#                                                                                                                    CompletionDate
# courseName                                       userid username  firstname phone1 department lastname moduleName
# Geographic Information System and Remote Sensing 134    e20170315 Kao Lyhov M      GRU        I4-WRI-A scorm                   13
